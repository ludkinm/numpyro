# %%
import jax
import numpyro
import numpyro.distributions as dist
import numpy as np
import matplotlib.pyplot as plt
from numpyro.infer import MCMC
from numpyro.infer.hug import HugHess

# %%
def normal(D=2, mu=0, sigma=1):
    with numpyro.plate('D', D):
        theta = numpyro.sample('theta', dist.Normal(mu, sigma))

# %%
kernel = HugHess(normal, step_size=1, trajectory_length=1)

mcmc = MCMC(kernel, num_warmup=0, num_samples=1000, num_chains=1)
rng_key = jax.random.PRNGKey(0)

mcmc.run(rng_key, D=2, mu=1, sigma=1, extra_fields=('potential_energy','accept_prob'))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# initializing init_params for hug
# finished init for hug
# r=Traced<ShapedArray(float32[2])>with<DynamicJaxprTrace(level=0/1)>
# z=Traced<ShapedArray(float32[2])>with<DynamicJaxprTrace(level=0/1)>
# logar=Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=0/1)>
# i=0
# z=Traced<ShapedArray(float32[2])>with<DynamicJaxprTrace(level=0/1)>
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-3-498bda5e6a8c> in <module>
#       5
# ----> 6 mcmc.run(rng_key, D=2, mu=1, sigma=1, extra_fields=('potential_energy','accept_prob'))
#       7
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/mcmc.py in run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     445         if self.num_chains == 1:
# --> 446             states_flat, last_state = partial_map_fn(map_args)
#     447             states = tree_map(lambda x: x[jnp.newaxis, ...], states_flat)
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/mcmc.py in _single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     322
# --> 323         collect_vals = fori_collect(lower_idx,
#     324                                     upper_idx,
#
# ~/Documents/projects/MCMC/numpyro/numpyro/util.py in fori_collect(lower, upper, body_fun, init_val, transform, progbar, return_last_val, collection_size, **progbar_opts)
#     225                 for i in t:
# --> 226                     vals = jit(_body_fn)(i, vals)
#     227                     t.set_description(progbar_desc(i), refresh=False)
#
# ~/Documents/projects/MCMC/numpyro/numpyro/util.py in _body_fn(i, vals)
#     206         val, collection, lower_idx = vals
# --> 207         val = body_fun(val)
#     208         i = jnp.where(i >= lower_idx, i - lower_idx, 0)
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/mcmc.py in _sample_fn_nojit_args(state, sampler, args, kwargs)
#     179     # state is a tuple of size 1 - containing HMCState
# --> 180     return sampler.sample(state[0], args, kwargs),
#     181
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/hug.py in sample(self, curr_state, model_args, model_kwargs)
#     311         # do hug
# --> 312         accept_prob, prop_z, prop_pe, prop_grad = huggy_hess(self._num_bounces, self._step_size, curr_z, curr_pe,
#     313                                                              self._potential_fn, rng_key_hug)
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/hug.py in huggy_hess(nbounce, step_size, z, z_pe, potential_fn, rng_key)
#      58             z, covar_inv=-flat_hessian(potential_fn, conditioner.unflatten(z)))
# ---> 59         g = flat_grad(potential_fn, z, conditioner)
#      60         print(f"{g=}")
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/hug_util.py in flat_grad(f, z, preconditioner)
#      10 def flat_grad(f, z, preconditioner):
# ---> 11     return preconditioner.flatten(grad(f)(preconditioner.unflatten(z)))
#      12
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/util.py in potential_energy(model, model_args, model_kwargs, params, enum)
#     156     # no param is needed for log_density computation because we already substitute
# --> 157     log_joint, model_trace = log_density_(substituted_model, model_args, model_kwargs, {})
#     158     return - log_joint
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/util.py in log_density(model, model_args, model_kwargs, params)
#      49     model = substitute(model, data=params)
# ---> 50     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#      51     log_joint = jnp.array(0.)
#
# ~/Documents/projects/MCMC/numpyro/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     155         """
# --> 156         self(*args, **kwargs)
#     157         return self.trace
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#
# <ipython-input-2-117d069434da> in normal(D, mu, sigma)
#       2     with numpyro.plate('D', D):
# ----> 3         theta = numpyro.sample('theta', dist.Normal(mu, sigma))
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in sample(name, fn, obs, rng_key, sample_shape, infer)
#     113     # ...and use apply_stack to send it to the Messengers
# --> 114     msg = apply_stack(initial_msg)
#     115     return msg['value']
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in apply_stack(msg)
#      30         if msg['type'] == 'sample':
# ---> 31             msg['value'], msg['intermediates'] = msg['fn'](*msg['args'],
#      32                                                            sample_intermediates=True,
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/distribution.py in __call__(self, *args, **kwargs)
#     254         if sample_intermediates:
# --> 255             return self.sample_with_intermediates(key, *args, **kwargs)
#     256         return self.sample(key, *args, **kwargs)
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/distribution.py in sample_with_intermediates(self, key, sample_shape)
#     215         """
# --> 216         return self.sample(key, sample_shape=sample_shape), []
#     217
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/distribution.py in sample(self, key, sample_shape)
#     383         batch_shape = expanded_sizes + interstitial_sizes
# --> 384         samples = self.base_dist(rng_key=key, sample_shape=sample_shape + batch_shape)
#     385         interstitial_idx = len(sample_shape) + len(expanded_sizes)
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/distribution.py in __call__(self, *args, **kwargs)
#     255             return self.sample_with_intermediates(key, *args, **kwargs)
# --> 256         return self.sample(key, *args, **kwargs)
#     257
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/continuous.py in sample(self, key, sample_shape)
#     914     def sample(self, key, sample_shape=()):
# --> 915         eps = random.normal(key, shape=sample_shape + self.batch_shape + self.event_shape)
#     916         return self.loc + eps * self.scale
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in normal(key, shape, dtype)
#     633   shape = abstract_arrays.canonicalize_shape(shape)
# --> 634   return _normal(key, shape, dtype)  # type: ignore
#     635
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in _normal(key, shape, dtype)
#     640   hi = np.array(1., dtype)
# --> 641   u = uniform(key, shape, dtype, lo, hi)
#     642   return np.array(np.sqrt(2), dtype) * lax.erf_inv(u)
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in uniform(key, shape, dtype, minval, maxval)
#     381   shape = abstract_arrays.canonicalize_shape(shape)
# --> 382   return _uniform(key, shape, dtype, minval, maxval)  # type: ignore
#     383
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in _uniform(key, shape, dtype, minval, maxval)
#     400
# --> 401   bits = _random_bits(key, nbits, shape)
#     402
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in _random_bits(key, bit_width, shape)
#     305   if not _is_prng_key(key):
# --> 306     raise TypeError("_random_bits got invalid prng key.")
#     307   if bit_width not in (8, 16, 32, 64):
#
# FilteredStackTrace: TypeError: _random_bits got invalid prng key.
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-498bda5e6a8c> in <module>
#       4 rng_key = jax.random.PRNGKey(0)
#       5
# ----> 6 mcmc.run(rng_key, D=2, mu=1, sigma=1, extra_fields=('potential_energy','accept_prob'))
#       7
#       8
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/mcmc.py in run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     444         map_args = (rng_key, init_state, init_params)
#     445         if self.num_chains == 1:
# --> 446             states_flat, last_state = partial_map_fn(map_args)
#     447             states = tree_map(lambda x: x[jnp.newaxis, ...], states_flat)
#     448         else:
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/mcmc.py in _single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     321         upper_idx = self._collection_params["upper"]
#     322
# --> 323         collect_vals = fori_collect(lower_idx,
#     324                                     upper_idx,
#     325                                     self._get_cached_fn(),
#
# ~/Documents/projects/MCMC/numpyro/numpyro/util.py in fori_collect(lower, upper, body_fun, init_val, transform, progbar, return_last_val, collection_size, **progbar_opts)
#     224             with tqdm.trange(upper) as t:
#     225                 for i in t:
# --> 226                     vals = jit(_body_fn)(i, vals)
#     227                     t.set_description(progbar_desc(i), refresh=False)
#     228                     if diagnostics_fn:
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     135   def reraise_with_filtered_traceback(*args, **kwargs):
#     136     try:
# --> 137       return fun(*args, **kwargs)
#     138     except Exception as e:
#     139       if not is_under_reraiser(e):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     207       _check_arg(arg)
#     208     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 209     out = xla.xla_call(
#     210         flat_fun,
#     211         *args_flat,
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1142
#    1143   def bind(self, fun, *args, **params):
# -> 1144     return call_bind(self, fun, *args, **params)
#    1145
#    1146   def process(self, trace, fun, tracers, params):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1133   tracers = map(top_trace.full_raise, args)
#    1134   with maybe_new_sublevel(top_trace):
# -> 1135     outs = primitive.process(top_trace, fun, tracers, params)
#    1136   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1137
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1145
#    1146   def process(self, trace, fun, tracers, params):
# -> 1147     return trace.process_call(self, fun, tracers, params)
#    1148
#    1149   def post_process(self, trace, out_tracers, params):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     575
#     576   def process_call(self, primitive, f, tracers, params):
# --> 577     return primitive.impl(f, *tracers, **params)
#     578   process_map = process_call
#     579
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     527
#     528 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
# --> 529   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     530                                *unsafe_map(arg_spec, args))
#     531   try:
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     232       fun.populate_stores(stores)
#     233     else:
# --> 234       ans = call(fun, *args)
#     235       cache[key] = (ans, fun.stores)
#     236     return ans
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     593   abstract_args, arg_devices = unzip2(arg_specs)
#     594   if config.omnistaging_enabled:
# --> 595     jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(fun, abstract_args)
#     596     if any(isinstance(c, core.Tracer) for c in consts):
#     597       raise core.UnexpectedTracerError("Encountered an unexpected tracer.")
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals)
#    1021     main.source_info = fun_sourceinfo(fun.f)  # type: ignore
#    1022     main.jaxpr_stack = ()  # type: ignore
# -> 1023     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1024     del main
#    1025   return jaxpr, out_avals, consts
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1002     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1003     in_tracers = map(trace.new_arg, in_avals)
# -> 1004     ans = fun.call_wrapped(*in_tracers)
#    1005     out_tracers = map(trace.full_raise, ans)
#    1006   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     149
#     150     try:
# --> 151       ans = self.f(*args, **dict(self.params, **kwargs))
#     152     except:
#     153       # Some transformations yield from inside context managers, so we have to
#
# ~/Documents/projects/MCMC/numpyro/numpyro/util.py in _body_fn(i, vals)
#     205     def _body_fn(i, vals):
#     206         val, collection, lower_idx = vals
# --> 207         val = body_fun(val)
#     208         i = jnp.where(i >= lower_idx, i - lower_idx, 0)
#     209         collection = ops.index_update(collection, i, ravel_pytree(transform(val))[0])
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/mcmc.py in _sample_fn_nojit_args(state, sampler, args, kwargs)
#     178 def _sample_fn_nojit_args(state, sampler, args, kwargs):
#     179     # state is a tuple of size 1 - containing HMCState
# --> 180     return sampler.sample(state[0], args, kwargs),
#     181
#     182
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/hug.py in sample(self, curr_state, model_args, model_kwargs)
#     310
#     311         # do hug
# --> 312         accept_prob, prop_z, prop_pe, prop_grad = huggy_hess(self._num_bounces, self._step_size, curr_z, curr_pe,
#     313                                                              self._potential_fn, rng_key_hug)
#     314
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/hug.py in huggy_hess(nbounce, step_size, z, z_pe, potential_fn, rng_key)
#      57         conditioner = preconditioner(
#      58             z, covar_inv=-flat_hessian(potential_fn, conditioner.unflatten(z)))
# ---> 59         g = flat_grad(potential_fn, z, conditioner)
#      60         print(f"{g=}")
#      61         Sg = conditioner.condition(g)
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/hug_util.py in flat_grad(f, z, preconditioner)
#       9
#      10 def flat_grad(f, z, preconditioner):
# ---> 11     return preconditioner.flatten(grad(f)(preconditioner.unflatten(z)))
#      12
#      13
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     135   def reraise_with_filtered_traceback(*args, **kwargs):
#     136     try:
# --> 137       return fun(*args, **kwargs)
#     138     except Exception as e:
#     139       if not is_under_reraiser(e):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/api.py in grad_f(*args, **kwargs)
#     742   @api_boundary
#     743   def grad_f(*args, **kwargs):
# --> 744     _, g = value_and_grad_f(*args, **kwargs)
#     745     return g
#     746
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     135   def reraise_with_filtered_traceback(*args, **kwargs):
#     136     try:
# --> 137       return fun(*args, **kwargs)
#     138     except Exception as e:
#     139       if not is_under_reraiser(e):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     802     tree_map(partial(_check_input_dtype_grad, holomorphic), dyn_args)
#     803     if not has_aux:
# --> 804       ans, vjp_py = _vjp(f_partial, *dyn_args)
#     805     else:
#     806       ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/api.py in _vjp(fun, has_aux, *primals)
#    1846   if not has_aux:
#    1847     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1848     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1849     out_tree = out_tree()
#    1850   else:
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     108 def vjp(traceable, primals, has_aux=False):
#     109   if not has_aux:
# --> 110     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     111   else:
#     112     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      95   _, in_tree = tree_flatten(((primals, primals), {}))
#      96   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# ---> 97   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#      98   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#      99   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate)
#     402   with core.new_main(JaxprTrace) as main:
#     403     fun = trace_to_subjaxpr(fun, main, instantiate)
# --> 404     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     405     assert not env
#     406     del main
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     149
#     150     try:
# --> 151       ans = self.f(*args, **dict(self.params, **kwargs))
#     152     except:
#     153       # Some transformations yield from inside context managers, so we have to
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/util.py in potential_energy(model, model_args, model_kwargs, params, enum)
#     155     substituted_model = substitute(model, substitute_fn=partial(_unconstrain_reparam, params))
#     156     # no param is needed for log_density computation because we already substitute
# --> 157     log_joint, model_trace = log_density_(substituted_model, model_args, model_kwargs, {})
#     158     return - log_joint
#     159
#
# ~/Documents/projects/MCMC/numpyro/numpyro/infer/util.py in log_density(model, model_args, model_kwargs, params)
#      48     """
#      49     model = substitute(model, data=params)
# ---> 50     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#      51     log_joint = jnp.array(0.)
#      52     for site in model_trace.values():
#
# ~/Documents/projects/MCMC/numpyro/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     154         :return: `OrderedDict` containing the execution trace.
#     155         """
# --> 156         self(*args, **kwargs)
#     157         return self.trace
#     158
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      66     def __call__(self, *args, **kwargs):
#      67         with self:
# ---> 68             return self.fn(*args, **kwargs)
#      69
#      70
#
# <ipython-input-2-117d069434da> in normal(D, mu, sigma)
#       1 def normal(D=2, mu=0, sigma=1):
#       2     with numpyro.plate('D', D):
# ----> 3         theta = numpyro.sample('theta', dist.Normal(mu, sigma))
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in sample(name, fn, obs, rng_key, sample_shape, infer)
#     112
#     113     # ...and use apply_stack to send it to the Messengers
# --> 114     msg = apply_stack(initial_msg)
#     115     return msg['value']
#     116
#
# ~/Documents/projects/MCMC/numpyro/numpyro/primitives.py in apply_stack(msg)
#      29     if msg['value'] is None:
#      30         if msg['type'] == 'sample':
# ---> 31             msg['value'], msg['intermediates'] = msg['fn'](*msg['args'],
#      32                                                            sample_intermediates=True,
#      33                                                            **msg['kwargs'])
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/distribution.py in __call__(self, *args, **kwargs)
#     253         sample_intermediates = kwargs.pop('sample_intermediates', False)
#     254         if sample_intermediates:
# --> 255             return self.sample_with_intermediates(key, *args, **kwargs)
#     256         return self.sample(key, *args, **kwargs)
#     257
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/distribution.py in sample_with_intermediates(self, key, sample_shape)
#     214         :rtype: numpy.ndarray
#     215         """
# --> 216         return self.sample(key, sample_shape=sample_shape), []
#     217
#     218     def log_prob(self, value):
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/distribution.py in sample(self, key, sample_shape)
#     382         expanded_sizes = tuple(self._expanded_sizes.values())
#     383         batch_shape = expanded_sizes + interstitial_sizes
# --> 384         samples = self.base_dist(rng_key=key, sample_shape=sample_shape + batch_shape)
#     385         interstitial_idx = len(sample_shape) + len(expanded_sizes)
#     386         interstitial_sample_dims = tuple(range(interstitial_idx, interstitial_idx + len(interstitial_sizes)))
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/distribution.py in __call__(self, *args, **kwargs)
#     254         if sample_intermediates:
#     255             return self.sample_with_intermediates(key, *args, **kwargs)
# --> 256         return self.sample(key, *args, **kwargs)
#     257
#     258     def to_event(self, reinterpreted_batch_ndims=None):
#
# ~/Documents/projects/MCMC/numpyro/numpyro/distributions/continuous.py in sample(self, key, sample_shape)
#     913
#     914     def sample(self, key, sample_shape=()):
# --> 915         eps = random.normal(key, shape=sample_shape + self.batch_shape + self.event_shape)
#     916         return self.loc + eps * self.scale
#     917
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in normal(key, shape, dtype)
#     632   dtype = dtypes.canonicalize_dtype(dtype)
#     633   shape = abstract_arrays.canonicalize_shape(shape)
# --> 634   return _normal(key, shape, dtype)  # type: ignore
#     635
#     636 @partial(jit, static_argnums=(1, 2))
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     135   def reraise_with_filtered_traceback(*args, **kwargs):
#     136     try:
# --> 137       return fun(*args, **kwargs)
#     138     except Exception as e:
#     139       if not is_under_reraiser(e):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     207       _check_arg(arg)
#     208     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 209     out = xla.xla_call(
#     210         flat_fun,
#     211         *args_flat,
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1142
#    1143   def bind(self, fun, *args, **params):
# -> 1144     return call_bind(self, fun, *args, **params)
#    1145
#    1146   def process(self, trace, fun, tracers, params):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1133   tracers = map(top_trace.full_raise, args)
#    1134   with maybe_new_sublevel(top_trace):
# -> 1135     outs = primitive.process(top_trace, fun, tracers, params)
#    1136   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1137
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1145
#    1146   def process(self, trace, fun, tracers, params):
# -> 1147     return trace.process_call(self, fun, tracers, params)
#    1148
#    1149   def post_process(self, trace, out_tracers, params):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#     938   def process_call(self, call_primitive, f, tracers, params):
#     939     in_avals = [t.aval for t in tracers]
# --> 940     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(f, self.main, in_avals)
#     941     if not jaxpr.eqns:
#     942       return core.eval_jaxpr(jaxpr, consts, *tracers)
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1002     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1003     in_tracers = map(trace.new_arg, in_avals)
# -> 1004     ans = fun.call_wrapped(*in_tracers)
#    1005     out_tracers = map(trace.full_raise, ans)
#    1006   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     149
#     150     try:
# --> 151       ans = self.f(*args, **dict(self.params, **kwargs))
#     152     except:
#     153       # Some transformations yield from inside context managers, so we have to
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in _normal(key, shape, dtype)
#     639   lo = np.nextafter(np.array(-1., dtype), 0., dtype=dtype)
#     640   hi = np.array(1., dtype)
# --> 641   u = uniform(key, shape, dtype, lo, hi)
#     642   return np.array(np.sqrt(2), dtype) * lax.erf_inv(u)
#     643
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in uniform(key, shape, dtype, minval, maxval)
#     380   dtype = dtypes.canonicalize_dtype(dtype)
#     381   shape = abstract_arrays.canonicalize_shape(shape)
# --> 382   return _uniform(key, shape, dtype, minval, maxval)  # type: ignore
#     383
#     384 @partial(jit, static_argnums=(1, 2))
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     135   def reraise_with_filtered_traceback(*args, **kwargs):
#     136     try:
# --> 137       return fun(*args, **kwargs)
#     138     except Exception as e:
#     139       if not is_under_reraiser(e):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     207       _check_arg(arg)
#     208     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 209     out = xla.xla_call(
#     210         flat_fun,
#     211         *args_flat,
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1142
#    1143   def bind(self, fun, *args, **params):
# -> 1144     return call_bind(self, fun, *args, **params)
#    1145
#    1146   def process(self, trace, fun, tracers, params):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1133   tracers = map(top_trace.full_raise, args)
#    1134   with maybe_new_sublevel(top_trace):
# -> 1135     outs = primitive.process(top_trace, fun, tracers, params)
#    1136   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1137
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1145
#    1146   def process(self, trace, fun, tracers, params):
# -> 1147     return trace.process_call(self, fun, tracers, params)
#    1148
#    1149   def post_process(self, trace, out_tracers, params):
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#     938   def process_call(self, call_primitive, f, tracers, params):
#     939     in_avals = [t.aval for t in tracers]
# --> 940     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(f, self.main, in_avals)
#     941     if not jaxpr.eqns:
#     942       return core.eval_jaxpr(jaxpr, consts, *tracers)
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1002     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1003     in_tracers = map(trace.new_arg, in_avals)
# -> 1004     ans = fun.call_wrapped(*in_tracers)
#    1005     out_tracers = map(trace.full_raise, ans)
#    1006   jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     149
#     150     try:
# --> 151       ans = self.f(*args, **dict(self.params, **kwargs))
#     152     except:
#     153       # Some transformations yield from inside context managers, so we have to
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in _uniform(key, shape, dtype, minval, maxval)
#     399     raise TypeError("uniform only accepts 32- or 64-bit dtypes.")
#     400
# --> 401   bits = _random_bits(key, nbits, shape)
#     402
#     403   # The strategy here is to randomize only the mantissa bits with an exponent of
#
# ~/Documents/projects/MCMC/numpyro/.venv/lib/python3.8/site-packages/jax/random.py in _random_bits(key, bit_width, shape)
#     304   """Sample uniform random bits of given width and shape using PRNG key."""
#     305   if not _is_prng_key(key):
# --> 306     raise TypeError("_random_bits got invalid prng key.")
#     307   if bit_width not in (8, 16, 32, 64):
#     308     raise TypeError("requires 8-, 16-, 32- or 64-bit field width.")
#
# TypeError: _random_bits got invalid prng key.

# %%
samples = mcmc.get_samples()
samples

# %%
plt.plot(samples["theta"])

# %%
plt.scatter(x=samples["theta"][:,0], y=samples["theta"][:,1])

# %%
pe, ap = [mcmc.get_extra_fields()[k] for k in ('potential_energy','accept_prob')]
plt.plot(pe)

# %%
plt.hist(ap, range=(0,1))
